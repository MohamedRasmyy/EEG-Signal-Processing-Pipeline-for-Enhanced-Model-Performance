# %%
import numpy as np
# Load the preprocessed data
X = np.load('X_all_ICA_ASR.npy')
Y = np.load('Y_all_ICA_ASR.npy')

# %%
import random
import torch
seed = 42
torch.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)

# %%
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset, random_split
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test=train_test_split(X,Y,test_size=.1,random_state=seed)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=seed)

X_train_flatten = X_train.reshape(-1, X_train.shape[-1])  # Shape: (num_train_epochs * num_channels, seq_len)
X_val_flatten = X_val.reshape(-1, X_val.shape[-1])        # Validation set
X_test_flatten = X_test.reshape(-1, X_test.shape[-1])  # Shape: (num_test_epochs * num_channels, seq_len)

mean = X_train_flatten.mean(axis=0)  # Compute the mean for each feature
X_train_centered = X_train_flatten - mean
X_val_centered = X_val_flatten - mean  # Center validation data using train set mean
X_test_centered = X_test_flatten - mean  # Apply the same mean to X_test

scaler = StandardScaler(with_mean=False)  # Disable mean subtraction since we already did it
X_train_scaled = scaler.fit_transform(X_train_centered)  # Fit on X_train
X_val_scaled = scaler.transform(X_val_centered)  # Apply the same scaler to validation data
X_test_scaled = scaler.transform(X_test_centered)  # Transform X_test using the same scaler

X_train_final = X_train_scaled.reshape(X_train.shape)  # Shape: (num_train_epochs, num_channels, seq_len)
X_val_final = X_val_scaled.reshape(X_val.shape)        # Shape: (num_val_epochs, num_channels, seq_len)
X_test_final = X_test_scaled.reshape(X_test.shape)  # Shape: (num_test_epochs, num_channels, seq_len)

print("Train set shape:", X_train_final.shape)
print("Validation set shape:", X_val_final.shape)
print("Test set shape:", X_test_final.shape)
# Out:
# Train set shape: (2098, 22, 1126)
# Validation set shape: (234, 22, 1126)
# Test set shape: (260, 22, 1126)

# %%
# 1. Convert Numpy Arrays to PyTorch Tensors
X_train1=torch.tensor(X_train_final,dtype=torch.float32)
X_val1=torch.tensor(X_val_final,dtype=torch.float32)
X_test1=torch.tensor(X_test_final,dtype=torch.float32)

y_train1=torch.tensor(y_train,dtype=torch.long)
y_val1=torch.tensor(y_val,dtype=torch.long)
y_test1=torch.tensor(y_test,dtype=torch.long)

# 2. Create TensorDatasets for Train, Validation, and Test Sets
train_dataset=TensorDataset(X_train1,y_train1)
val_dataset=TensorDataset(X_val1,y_val1)
test_dataset=TensorDataset(X_test1,y_test1)

# 3. Create DataLoaders for Batch Processing
train_loader=DataLoader(train_dataset,batch_size=100,shuffle=True)
val_loader=DataLoader(val_dataset,batch_size=100,shuffle=False)
test_loader=DataLoader(test_dataset,batch_size=100,shuffle=False)

# %%
# Define the CNN-LSTM model
class CNNLSTM(nn.Module):
    def __init__(self, input_channels, output_channel, lstm_hidden_dim1, lstm_hidden_dim2, output_channel2, num_classes):
        super(CNNLSTM, self).__init__()
        
        #First CNN Layer
        self.cnn = nn.Sequential(
            nn.Conv1d(input_channels, output_channel, padding=0, kernel_size=20, stride=4),
            nn.ReLU(),
            nn.BatchNorm1d(output_channel),
            nn.MaxPool1d(kernel_size=4, stride=4),
            nn.Dropout(0.5)
        )
        
        #First LSTM layers with bidirectional
        self.lstm1 = nn.LSTM(output_channel, hidden_size=lstm_hidden_dim1, num_layers=1, batch_first=True, bidirectional=True)
        self.dropout1 = nn.Dropout(0.5)
        
        #Second CNN Layer
        self.cnn2 = nn.Sequential(
            nn.Conv1d(lstm_hidden_dim1*2, output_channel2, padding=0, kernel_size=10, stride=4),
            nn.ReLU(),
            nn.BatchNorm1d(output_channel2),
            nn.MaxPool1d(kernel_size=4, stride=4),
            nn.Dropout(0.5)
        )
        
        #Second Lstm layer with bidirectional
        self.lstm2 = nn.LSTM(output_channel2, lstm_hidden_dim2, num_layers=1, batch_first=True, bidirectional=True)
        self.dropout2 = nn.Dropout(0.5)
        
        # Fully connected layer
        self.fc = nn.Linear(lstm_hidden_dim2 * 2 * 3, num_classes)
        self._initialize_weights()

    def forward(self, x):
        
        x = self.cnn(x)  # Apply CNN
        x = x.permute(0, 2, 1)  # Permute for LSTM (batch_size, seq_len, num_features)
        
        x, _ = self.lstm1(x)  # First LSTM layer
        x = self.dropout1(x)
        
        x = x.permute(0, 2, 1)  # Permute back for CNN
        x = self.cnn2(x)  # Apply second CNN layer
        
        x = x.permute(0, 2, 1)  # Permute for LSTM
        
        x, _ = self.lstm2(x) # Second LSTM layer
        x = self.dropout2(x)

        x = x.contiguous().view(x.size(0), -1)  # Flatten for FC layer
        x = self.fc(x)  # Apply fully connected layer
        return x

    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv1d) or isinstance(m, nn.Linear):
                nn.init.kaiming_normal_(m.weight, nonlinearity='relu')
                if m.bias is not None:
                    nn.init.zeros_(m.bias)
            elif isinstance(m, nn.LSTM):
                for name, param in m.named_parameters():
                    if 'weight_ih' in name:
                        nn.init.xavier_normal_(param)
                    elif 'weight_hh' in name:
                        nn.init.orthogonal_(param)
                    elif 'bias' in name:
                        nn.init.zeros_(param) # Set all biases to 0, including forget gate
                       
                        

input_channels = 22  
output_channel = 40
output_channel2 = 30
lstm_hidden_dim1 = 70
lstm_hidden_dim2 = 50
num_classes = 4  

# Instantiate the model
model = CNNLSTM(input_channels, output_channel, lstm_hidden_dim1, lstm_hidden_dim2, output_channel2, num_classes)
# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0007, weight_decay=.002)
# Training the model
num_epochs = 250
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct_train = 0
    total_train = 0

    # Training phase
    for inputs, labels in train_loader:
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        
        _, predicted = torch.max(outputs.data, 1)
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()

    train_accuracy = 100 * correct_train / total_train
    train_loss = running_loss / len(train_loader)
    
    # Validation phase
    model.eval()
    correct_val = 0
    total_val = 0
    running_val_loss = 0.0
    with torch.no_grad():
        for inputs, labels in val_loader:
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            running_val_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total_val += labels.size(0)
            correct_val += (predicted == labels).sum().item()

    val_accuracy = 100 * correct_val / total_val
    val_loss = running_val_loss / len(val_loader)
    
    print(f'Epoch [{epoch+1}/{num_epochs}], '
          f'Train Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.2f}%, '
          f'Val Loss: {val_loss:.4f}, Val Accuracy: {val_accuracy:.2f}%')
# Testing Phase
model.eval()
correct = 0
total = 0
with torch.no_grad():	
    for inputs, labels in test_loader:
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

final_accuracy = 100 * correct / total
print(f'Final accuracy on test set: {final_accuracy:.2f}%')
# Out:
# Epoch [1/250], Train Loss: 1.4402, Train Accuracy: 23.36%, Val Loss: 1.3856, Val Accuracy: 25.64%
# Epoch [2/250], Train Loss: 1.4158, Train Accuracy: 25.88%, Val Loss: 1.3855, Val Accuracy: 27.35%
# Epoch [3/250], Train Loss: 1.4062, Train Accuracy: 26.64%, Val Loss: 1.3809, Val Accuracy: 30.34%
# Epoch [4/250], Train Loss: 1.4021, Train Accuracy: 26.50%, Val Loss: 1.3737, Val Accuracy: 30.34%
# Epoch [5/250], Train Loss: 1.3933, Train Accuracy: 27.12%, Val Loss: 1.3603, Val Accuracy: 30.34%
# Epoch [6/250], Train Loss: 1.3945, Train Accuracy: 26.45%, Val Loss: 1.3612, Val Accuracy: 30.77%
# Epoch [7/250], Train Loss: 1.3884, Train Accuracy: 27.88%, Val Loss: 1.3521, Val Accuracy: 29.49%
# Epoch [8/250], Train Loss: 1.3806, Train Accuracy: 30.27%, Val Loss: 1.3435, Val Accuracy: 31.62%
# Epoch [9/250], Train Loss: 1.3655, Train Accuracy: 30.98%, Val Loss: 1.3318, Val Accuracy: 33.76%
# Epoch [10/250], Train Loss: 1.3613, Train Accuracy: 32.32%, Val Loss: 1.3254, Val Accuracy: 36.75%
# Epoch [11/250], Train Loss: 1.3451, Train Accuracy: 30.65%, Val Loss: 1.3235, Val Accuracy: 35.47%
# Epoch [12/250], Train Loss: 1.3199, Train Accuracy: 34.46%, Val Loss: 1.2893, Val Accuracy: 36.32%
# Epoch [13/250], Train Loss: 1.3162, Train Accuracy: 34.75%, Val Loss: 1.2548, Val Accuracy: 39.32%
# Epoch [14/250], Train Loss: 1.2876, Train Accuracy: 37.42%, Val Loss: 1.2878, Val Accuracy: 44.44%
# Epoch [15/250], Train Loss: 1.2954, Train Accuracy: 37.51%, Val Loss: 1.2808, Val Accuracy: 38.89%
# Epoch [16/250], Train Loss: 1.2761, Train Accuracy: 38.66%, Val Loss: 1.2215, Val Accuracy: 43.16%
# Epoch [17/250], Train Loss: 1.2678, Train Accuracy: 39.85%, Val Loss: 1.1929, Val Accuracy: 43.16%
# Epoch [18/250], Train Loss: 1.2619, Train Accuracy: 38.80%, Val Loss: 1.2086, Val Accuracy: 40.17%
# Epoch [19/250], Train Loss: 1.2439, Train Accuracy: 41.42%, Val Loss: 1.2010, Val Accuracy: 40.60%
# Epoch [20/250], Train Loss: 1.2491, Train Accuracy: 40.90%, Val Loss: 1.1626, Val Accuracy: 42.74%
# Epoch [21/250], Train Loss: 1.2247, Train Accuracy: 43.04%, Val Loss: 1.1195, Val Accuracy: 49.15%
# Epoch [22/250], Train Loss: 1.2145, Train Accuracy: 42.95%, Val Loss: 1.1274, Val Accuracy: 44.87%
# Epoch [23/250], Train Loss: 1.2020, Train Accuracy: 43.76%, Val Loss: 1.2322, Val Accuracy: 44.44%
# Epoch [24/250], Train Loss: 1.1878, Train Accuracy: 45.00%, Val Loss: 1.1195, Val Accuracy: 44.87%
# Epoch [25/250], Train Loss: 1.1555, Train Accuracy: 46.23%, Val Loss: 1.1144, Val Accuracy: 44.44%
# Epoch [26/250], Train Loss: 1.1584, Train Accuracy: 46.81%, Val Loss: 1.0663, Val Accuracy: 50.85%
# Epoch [27/250], Train Loss: 1.1733, Train Accuracy: 46.33%, Val Loss: 1.0422, Val Accuracy: 51.28%
# Epoch [28/250], Train Loss: 1.1410, Train Accuracy: 47.57%, Val Loss: 1.0706, Val Accuracy: 46.15%
# Epoch [29/250], Train Loss: 1.1265, Train Accuracy: 48.81%, Val Loss: 1.1101, Val Accuracy: 47.44%
# Epoch [30/250], Train Loss: 1.1147, Train Accuracy: 48.57%, Val Loss: 1.0230, Val Accuracy: 52.14%
# Epoch [31/250], Train Loss: 1.1051, Train Accuracy: 50.10%, Val Loss: 1.0396, Val Accuracy: 50.85%
# Epoch [32/250], Train Loss: 1.1086, Train Accuracy: 51.10%, Val Loss: 1.0611, Val Accuracy: 49.57%
# Epoch [33/250], Train Loss: 1.0905, Train Accuracy: 50.10%, Val Loss: 1.0036, Val Accuracy: 57.26%
# Epoch [34/250], Train Loss: 1.0645, Train Accuracy: 52.96%, Val Loss: 0.9512, Val Accuracy: 52.56%
# Epoch [35/250], Train Loss: 1.0736, Train Accuracy: 51.48%, Val Loss: 1.0696, Val Accuracy: 50.85%
# Epoch [36/250], Train Loss: 1.0706, Train Accuracy: 51.00%, Val Loss: 0.9712, Val Accuracy: 57.69%
# Epoch [37/250], Train Loss: 1.0588, Train Accuracy: 52.10%, Val Loss: 0.9660, Val Accuracy: 54.70%
# Epoch [38/250], Train Loss: 1.0672, Train Accuracy: 53.29%, Val Loss: 0.9481, Val Accuracy: 57.26%
# Epoch [39/250], Train Loss: 1.0407, Train Accuracy: 52.29%, Val Loss: 1.0351, Val Accuracy: 51.71%
# Epoch [40/250], Train Loss: 1.0453, Train Accuracy: 53.72%, Val Loss: 0.9755, Val Accuracy: 56.41%
# Epoch [41/250], Train Loss: 1.0222, Train Accuracy: 54.96%, Val Loss: 0.9711, Val Accuracy: 55.13%
# Epoch [42/250], Train Loss: 1.0273, Train Accuracy: 55.86%, Val Loss: 0.9197, Val Accuracy: 55.56%
# Epoch [43/250], Train Loss: 1.0272, Train Accuracy: 53.29%, Val Loss: 0.9996, Val Accuracy: 52.56%
# Epoch [44/250], Train Loss: 1.0164, Train Accuracy: 53.96%, Val Loss: 0.9819, Val Accuracy: 53.85%
# Epoch [45/250], Train Loss: 1.0213, Train Accuracy: 55.24%, Val Loss: 1.0968, Val Accuracy: 50.00%
# Epoch [46/250], Train Loss: 1.0282, Train Accuracy: 55.48%, Val Loss: 0.9656, Val Accuracy: 55.13%
# Epoch [47/250], Train Loss: 1.0235, Train Accuracy: 55.29%, Val Loss: 0.9753, Val Accuracy: 52.99%
# Epoch [48/250], Train Loss: 0.9876, Train Accuracy: 55.67%, Val Loss: 0.9746, Val Accuracy: 54.27%
# Epoch [49/250], Train Loss: 1.0035, Train Accuracy: 56.10%, Val Loss: 0.9656, Val Accuracy: 54.70%
# Epoch [50/250], Train Loss: 0.9958, Train Accuracy: 56.05%, Val Loss: 0.9423, Val Accuracy: 53.85%
# Epoch [51/250], Train Loss: 0.9780, Train Accuracy: 56.39%, Val Loss: 0.9547, Val Accuracy: 54.27%
# Epoch [52/250], Train Loss: 0.9785, Train Accuracy: 57.24%, Val Loss: 0.9243, Val Accuracy: 55.56%
# Epoch [53/250], Train Loss: 0.9884, Train Accuracy: 57.48%, Val Loss: 0.9394, Val Accuracy: 55.98%
# Epoch [54/250], Train Loss: 0.9549, Train Accuracy: 58.63%, Val Loss: 0.9869, Val Accuracy: 54.27%
# Epoch [55/250], Train Loss: 0.9851, Train Accuracy: 57.05%, Val Loss: 1.0115, Val Accuracy: 51.71%
# Epoch [56/250], Train Loss: 0.9589, Train Accuracy: 58.67%, Val Loss: 0.9387, Val Accuracy: 53.85%
# Epoch [57/250], Train Loss: 0.9562, Train Accuracy: 58.77%, Val Loss: 1.0166, Val Accuracy: 52.14%
# Epoch [58/250], Train Loss: 0.9404, Train Accuracy: 59.91%, Val Loss: 0.8838, Val Accuracy: 61.11%
# Epoch [59/250], Train Loss: 0.9394, Train Accuracy: 60.68%, Val Loss: 0.9562, Val Accuracy: 55.13%
# Epoch [60/250], Train Loss: 0.9625, Train Accuracy: 57.34%, Val Loss: 0.9172, Val Accuracy: 55.56%
# Epoch [61/250], Train Loss: 0.9278, Train Accuracy: 59.68%, Val Loss: 0.9047, Val Accuracy: 59.83%
# Epoch [62/250], Train Loss: 0.9197, Train Accuracy: 60.10%, Val Loss: 0.9246, Val Accuracy: 56.41%
# Epoch [63/250], Train Loss: 0.9201, Train Accuracy: 60.49%, Val Loss: 0.8974, Val Accuracy: 60.68%
# Epoch [64/250], Train Loss: 0.9135, Train Accuracy: 60.77%, Val Loss: 0.9053, Val Accuracy: 57.26%
# Epoch [65/250], Train Loss: 0.9153, Train Accuracy: 62.06%, Val Loss: 0.8590, Val Accuracy: 59.83%
# Epoch [66/250], Train Loss: 0.9280, Train Accuracy: 59.39%, Val Loss: 0.8809, Val Accuracy: 61.97%
# Epoch [67/250], Train Loss: 0.9193, Train Accuracy: 61.30%, Val Loss: 0.9417, Val Accuracy: 58.97%
# Epoch [68/250], Train Loss: 0.9087, Train Accuracy: 61.49%, Val Loss: 0.9399, Val Accuracy: 59.83%
# Epoch [69/250], Train Loss: 0.9146, Train Accuracy: 59.63%, Val Loss: 0.8684, Val Accuracy: 63.68%
# Epoch [70/250], Train Loss: 0.9167, Train Accuracy: 61.30%, Val Loss: 0.8745, Val Accuracy: 63.68%
# Epoch [71/250], Train Loss: 0.8941, Train Accuracy: 63.73%, Val Loss: 0.8893, Val Accuracy: 58.97%
# Epoch [72/250], Train Loss: 0.8849, Train Accuracy: 61.11%, Val Loss: 0.8824, Val Accuracy: 57.69%
# Epoch [73/250], Train Loss: 0.9054, Train Accuracy: 61.58%, Val Loss: 0.8687, Val Accuracy: 58.97%
# Epoch [74/250], Train Loss: 0.8839, Train Accuracy: 62.15%, Val Loss: 0.9105, Val Accuracy: 59.40%
# Epoch [75/250], Train Loss: 0.8615, Train Accuracy: 63.92%, Val Loss: 0.8181, Val Accuracy: 61.97%
# Epoch [76/250], Train Loss: 0.8938, Train Accuracy: 61.06%, Val Loss: 0.8344, Val Accuracy: 59.40%
# Epoch [77/250], Train Loss: 0.8650, Train Accuracy: 63.44%, Val Loss: 0.9030, Val Accuracy: 58.97%
# Epoch [78/250], Train Loss: 0.8764, Train Accuracy: 62.82%, Val Loss: 0.8619, Val Accuracy: 55.98%
# Epoch [79/250], Train Loss: 0.8482, Train Accuracy: 64.16%, Val Loss: 0.8281, Val Accuracy: 60.26%
# Epoch [80/250], Train Loss: 0.8475, Train Accuracy: 64.78%, Val Loss: 0.8498, Val Accuracy: 60.68%
# Epoch [81/250], Train Loss: 0.8514, Train Accuracy: 65.11%, Val Loss: 0.8398, Val Accuracy: 64.53%
# Epoch [82/250], Train Loss: 0.8479, Train Accuracy: 64.87%, Val Loss: 0.8429, Val Accuracy: 60.68%
# Epoch [83/250], Train Loss: 0.8492, Train Accuracy: 66.02%, Val Loss: 0.8604, Val Accuracy: 61.97%
# Epoch [84/250], Train Loss: 0.8543, Train Accuracy: 62.54%, Val Loss: 0.8377, Val Accuracy: 60.26%
# Epoch [85/250], Train Loss: 0.8347, Train Accuracy: 64.68%, Val Loss: 0.9190, Val Accuracy: 54.70%
# Epoch [86/250], Train Loss: 0.8343, Train Accuracy: 65.49%, Val Loss: 0.9216, Val Accuracy: 59.83%
# Epoch [87/250], Train Loss: 0.8258, Train Accuracy: 66.11%, Val Loss: 0.8141, Val Accuracy: 60.68%
# Epoch [88/250], Train Loss: 0.8340, Train Accuracy: 65.92%, Val Loss: 0.8466, Val Accuracy: 62.82%
# Epoch [89/250], Train Loss: 0.8369, Train Accuracy: 65.68%, Val Loss: 0.8405, Val Accuracy: 62.82%
# Epoch [90/250], Train Loss: 0.7905, Train Accuracy: 67.40%, Val Loss: 0.8181, Val Accuracy: 63.68%
# Epoch [91/250], Train Loss: 0.7973, Train Accuracy: 66.11%, Val Loss: 0.8078, Val Accuracy: 65.38%
# Epoch [92/250], Train Loss: 0.8382, Train Accuracy: 64.54%, Val Loss: 0.8124, Val Accuracy: 64.53%
# Epoch [93/250], Train Loss: 0.8085, Train Accuracy: 66.92%, Val Loss: 0.8671, Val Accuracy: 59.83%
# Epoch [94/250], Train Loss: 0.7975, Train Accuracy: 67.30%, Val Loss: 0.8163, Val Accuracy: 58.97%
# Epoch [95/250], Train Loss: 0.8054, Train Accuracy: 67.11%, Val Loss: 0.8946, Val Accuracy: 58.12%
# Epoch [96/250], Train Loss: 0.7920, Train Accuracy: 67.92%, Val Loss: 0.8530, Val Accuracy: 59.83%
# Epoch [97/250], Train Loss: 0.7994, Train Accuracy: 66.68%, Val Loss: 0.9149, Val Accuracy: 56.41%
# Epoch [98/250], Train Loss: 0.7952, Train Accuracy: 67.54%, Val Loss: 0.8103, Val Accuracy: 67.95%
# Epoch [99/250], Train Loss: 0.7723, Train Accuracy: 68.59%, Val Loss: 0.8454, Val Accuracy: 63.25%
# Epoch [100/250], Train Loss: 0.7786, Train Accuracy: 67.06%, Val Loss: 0.8686, Val Accuracy: 58.97%
# Epoch [101/250], Train Loss: 0.7989, Train Accuracy: 67.49%, Val Loss: 0.9193, Val Accuracy: 60.26%
# Epoch [102/250], Train Loss: 0.7522, Train Accuracy: 69.83%, Val Loss: 0.8240, Val Accuracy: 64.53%
# Epoch [103/250], Train Loss: 0.7674, Train Accuracy: 68.40%, Val Loss: 0.7771, Val Accuracy: 66.24%
# Epoch [104/250], Train Loss: 0.7516, Train Accuracy: 68.68%, Val Loss: 0.8093, Val Accuracy: 64.96%
# Epoch [105/250], Train Loss: 0.7851, Train Accuracy: 68.35%, Val Loss: 0.9719, Val Accuracy: 59.83%
# Epoch [106/250], Train Loss: 0.7789, Train Accuracy: 68.78%, Val Loss: 0.9871, Val Accuracy: 58.55%
# Epoch [107/250], Train Loss: 0.7726, Train Accuracy: 68.88%, Val Loss: 0.9371, Val Accuracy: 57.26%
# Epoch [108/250], Train Loss: 0.7489, Train Accuracy: 69.45%, Val Loss: 0.8483, Val Accuracy: 61.97%
# Epoch [109/250], Train Loss: 0.7488, Train Accuracy: 70.26%, Val Loss: 0.8426, Val Accuracy: 64.10%
# Epoch [110/250], Train Loss: 0.7439, Train Accuracy: 69.64%, Val Loss: 0.7868, Val Accuracy: 60.68%
# Epoch [111/250], Train Loss: 0.7459, Train Accuracy: 68.59%, Val Loss: 0.8100, Val Accuracy: 61.11%
# Epoch [112/250], Train Loss: 0.7578, Train Accuracy: 69.02%, Val Loss: 0.8874, Val Accuracy: 64.10%
# Epoch [113/250], Train Loss: 0.7528, Train Accuracy: 69.69%, Val Loss: 0.7945, Val Accuracy: 62.82%
# Epoch [114/250], Train Loss: 0.7379, Train Accuracy: 69.73%, Val Loss: 0.8338, Val Accuracy: 63.25%
# Epoch [115/250], Train Loss: 0.7187, Train Accuracy: 70.21%, Val Loss: 0.8052, Val Accuracy: 62.82%
# Epoch [116/250], Train Loss: 0.7433, Train Accuracy: 70.02%, Val Loss: 0.7991, Val Accuracy: 64.53%
# Epoch [117/250], Train Loss: 0.7286, Train Accuracy: 69.88%, Val Loss: 0.8218, Val Accuracy: 64.96%
# Epoch [118/250], Train Loss: 0.7338, Train Accuracy: 69.69%, Val Loss: 0.8720, Val Accuracy: 62.39%
# Epoch [119/250], Train Loss: 0.7229, Train Accuracy: 69.78%, Val Loss: 0.8734, Val Accuracy: 60.68%
# Epoch [120/250], Train Loss: 0.7269, Train Accuracy: 70.64%, Val Loss: 0.7945, Val Accuracy: 64.53%
# Epoch [121/250], Train Loss: 0.7233, Train Accuracy: 70.40%, Val Loss: 0.8606, Val Accuracy: 59.83%
# Epoch [122/250], Train Loss: 0.7144, Train Accuracy: 71.45%, Val Loss: 0.8455, Val Accuracy: 64.53%
# Epoch [123/250], Train Loss: 0.7091, Train Accuracy: 71.21%, Val Loss: 0.8240, Val Accuracy: 63.68%
# Epoch [124/250], Train Loss: 0.7098, Train Accuracy: 71.02%, Val Loss: 0.8940, Val Accuracy: 61.11%
# Epoch [125/250], Train Loss: 0.6954, Train Accuracy: 71.93%, Val Loss: 0.7997, Val Accuracy: 65.38%
# Epoch [126/250], Train Loss: 0.6810, Train Accuracy: 72.55%, Val Loss: 0.8185, Val Accuracy: 63.25%
# Epoch [127/250], Train Loss: 0.6872, Train Accuracy: 72.16%, Val Loss: 0.8687, Val Accuracy: 60.26%
# Epoch [128/250], Train Loss: 0.6929, Train Accuracy: 72.50%, Val Loss: 0.8216, Val Accuracy: 63.68%
# Epoch [129/250], Train Loss: 0.7205, Train Accuracy: 71.07%, Val Loss: 0.9135, Val Accuracy: 60.68%
# Epoch [130/250], Train Loss: 0.7126, Train Accuracy: 71.35%, Val Loss: 0.8908, Val Accuracy: 60.26%
# Epoch [131/250], Train Loss: 0.6906, Train Accuracy: 73.07%, Val Loss: 0.8206, Val Accuracy: 68.38%
# Epoch [132/250], Train Loss: 0.6754, Train Accuracy: 73.50%, Val Loss: 0.8551, Val Accuracy: 61.54%
# Epoch [133/250], Train Loss: 0.7026, Train Accuracy: 72.59%, Val Loss: 0.8595, Val Accuracy: 63.68%
# Epoch [134/250], Train Loss: 0.6830, Train Accuracy: 72.93%, Val Loss: 0.8339, Val Accuracy: 62.82%
# Epoch [135/250], Train Loss: 0.6714, Train Accuracy: 74.07%, Val Loss: 0.8247, Val Accuracy: 63.25%
# Epoch [136/250], Train Loss: 0.6849, Train Accuracy: 74.40%, Val Loss: 0.8626, Val Accuracy: 60.68%
# Epoch [137/250], Train Loss: 0.6839, Train Accuracy: 72.50%, Val Loss: 0.8307, Val Accuracy: 65.38%
# Epoch [138/250], Train Loss: 0.6926, Train Accuracy: 72.31%, Val Loss: 0.7938, Val Accuracy: 64.53%
# Epoch [139/250], Train Loss: 0.6811, Train Accuracy: 73.31%, Val Loss: 0.7621, Val Accuracy: 64.53%
# Epoch [140/250], Train Loss: 0.6657, Train Accuracy: 73.45%, Val Loss: 0.8095, Val Accuracy: 66.24%
# Epoch [141/250], Train Loss: 0.6542, Train Accuracy: 72.16%, Val Loss: 0.8355, Val Accuracy: 64.96%
# Epoch [142/250], Train Loss: 0.6629, Train Accuracy: 73.59%, Val Loss: 0.8280, Val Accuracy: 64.10%
# Epoch [143/250], Train Loss: 0.6585, Train Accuracy: 74.21%, Val Loss: 0.8864, Val Accuracy: 61.97%
# Epoch [144/250], Train Loss: 0.6375, Train Accuracy: 75.41%, Val Loss: 0.8855, Val Accuracy: 62.39%
# Epoch [145/250], Train Loss: 0.6754, Train Accuracy: 73.69%, Val Loss: 0.8697, Val Accuracy: 58.55%
# Epoch [146/250], Train Loss: 0.6416, Train Accuracy: 74.36%, Val Loss: 0.8434, Val Accuracy: 64.10%
# Epoch [147/250], Train Loss: 0.6643, Train Accuracy: 73.78%, Val Loss: 0.7731, Val Accuracy: 66.24%
# Epoch [148/250], Train Loss: 0.6738, Train Accuracy: 73.74%, Val Loss: 0.8238, Val Accuracy: 59.40%
# Epoch [149/250], Train Loss: 0.6429, Train Accuracy: 75.21%, Val Loss: 0.8061, Val Accuracy: 66.67%
# Epoch [150/250], Train Loss: 0.6469, Train Accuracy: 73.83%, Val Loss: 0.7776, Val Accuracy: 62.39%
# Epoch [151/250], Train Loss: 0.6345, Train Accuracy: 75.88%, Val Loss: 0.8088, Val Accuracy: 63.25%
# Epoch [152/250], Train Loss: 0.6184, Train Accuracy: 76.22%, Val Loss: 0.8196, Val Accuracy: 64.10%
# Epoch [153/250], Train Loss: 0.6444, Train Accuracy: 74.36%, Val Loss: 0.7810, Val Accuracy: 64.10%
# Epoch [154/250], Train Loss: 0.6285, Train Accuracy: 75.79%, Val Loss: 0.7894, Val Accuracy: 66.24%
# Epoch [155/250], Train Loss: 0.6537, Train Accuracy: 74.79%, Val Loss: 0.7621, Val Accuracy: 65.38%
# Epoch [156/250], Train Loss: 0.6641, Train Accuracy: 73.78%, Val Loss: 0.8573, Val Accuracy: 60.68%
# Epoch [157/250], Train Loss: 0.6099, Train Accuracy: 76.26%, Val Loss: 0.8593, Val Accuracy: 64.10%
# Epoch [158/250], Train Loss: 0.6448, Train Accuracy: 74.93%, Val Loss: 0.8413, Val Accuracy: 63.68%
# Epoch [159/250], Train Loss: 0.6246, Train Accuracy: 75.74%, Val Loss: 0.8206, Val Accuracy: 63.25%
# Epoch [160/250], Train Loss: 0.6056, Train Accuracy: 75.98%, Val Loss: 0.8716, Val Accuracy: 61.54%
# Epoch [161/250], Train Loss: 0.6367, Train Accuracy: 73.78%, Val Loss: 0.7892, Val Accuracy: 64.53%
# Epoch [162/250], Train Loss: 0.6198, Train Accuracy: 75.41%, Val Loss: 0.7885, Val Accuracy: 67.95%
# Epoch [163/250], Train Loss: 0.5903, Train Accuracy: 77.55%, Val Loss: 0.9180, Val Accuracy: 61.11%
# Epoch [164/250], Train Loss: 0.6294, Train Accuracy: 75.07%, Val Loss: 0.7347, Val Accuracy: 70.51%
# Epoch [165/250], Train Loss: 0.6162, Train Accuracy: 75.36%, Val Loss: 0.8249, Val Accuracy: 65.81%
# Epoch [166/250], Train Loss: 0.6242, Train Accuracy: 76.22%, Val Loss: 0.8834, Val Accuracy: 65.38%
# Epoch [167/250], Train Loss: 0.5992, Train Accuracy: 76.55%, Val Loss: 0.8324, Val Accuracy: 65.81%
# Epoch [168/250], Train Loss: 0.6028, Train Accuracy: 76.64%, Val Loss: 0.7924, Val Accuracy: 63.68%
# Epoch [169/250], Train Loss: 0.6143, Train Accuracy: 77.17%, Val Loss: 0.7517, Val Accuracy: 67.52%
# Epoch [170/250], Train Loss: 0.6025, Train Accuracy: 76.69%, Val Loss: 0.7732, Val Accuracy: 67.95%
# Epoch [171/250], Train Loss: 0.5829, Train Accuracy: 77.22%, Val Loss: 0.7629, Val Accuracy: 66.67%
# Epoch [172/250], Train Loss: 0.5784, Train Accuracy: 78.03%, Val Loss: 0.8152, Val Accuracy: 62.39%
# Epoch [173/250], Train Loss: 0.5978, Train Accuracy: 76.22%, Val Loss: 0.8583, Val Accuracy: 63.68%
# Epoch [174/250], Train Loss: 0.6310, Train Accuracy: 74.83%, Val Loss: 0.7734, Val Accuracy: 69.23%
# Epoch [175/250], Train Loss: 0.6038, Train Accuracy: 76.02%, Val Loss: 0.7592, Val Accuracy: 67.52%
# Epoch [176/250], Train Loss: 0.5767, Train Accuracy: 78.03%, Val Loss: 0.9582, Val Accuracy: 59.40%
# Epoch [177/250], Train Loss: 0.5792, Train Accuracy: 77.41%, Val Loss: 0.8252, Val Accuracy: 61.54%
# Epoch [178/250], Train Loss: 0.6240, Train Accuracy: 74.93%, Val Loss: 0.8957, Val Accuracy: 63.68%
# Epoch [179/250], Train Loss: 0.5758, Train Accuracy: 78.03%, Val Loss: 0.8166, Val Accuracy: 65.81%
# Epoch [180/250], Train Loss: 0.5616, Train Accuracy: 78.36%, Val Loss: 0.8433, Val Accuracy: 64.53%
# Epoch [181/250], Train Loss: 0.5853, Train Accuracy: 76.84%, Val Loss: 0.7634, Val Accuracy: 67.09%
# Epoch [182/250], Train Loss: 0.5882, Train Accuracy: 76.69%, Val Loss: 0.7914, Val Accuracy: 62.82%
# Epoch [183/250], Train Loss: 0.5786, Train Accuracy: 77.31%, Val Loss: 0.7241, Val Accuracy: 62.82%
# Epoch [184/250], Train Loss: 0.5765, Train Accuracy: 78.41%, Val Loss: 0.8748, Val Accuracy: 67.52%
# Epoch [185/250], Train Loss: 0.6103, Train Accuracy: 76.22%, Val Loss: 0.8135, Val Accuracy: 63.68%
# Epoch [186/250], Train Loss: 0.5639, Train Accuracy: 78.98%, Val Loss: 0.9068, Val Accuracy: 63.25%
# Epoch [187/250], Train Loss: 0.5553, Train Accuracy: 79.22%, Val Loss: 0.7895, Val Accuracy: 66.24%
# Epoch [188/250], Train Loss: 0.5596, Train Accuracy: 78.50%, Val Loss: 0.8139, Val Accuracy: 66.67%
# Epoch [189/250], Train Loss: 0.5714, Train Accuracy: 78.31%, Val Loss: 0.8042, Val Accuracy: 64.10%
# Epoch [190/250], Train Loss: 0.5458, Train Accuracy: 79.46%, Val Loss: 0.8342, Val Accuracy: 64.96%
# Epoch [191/250], Train Loss: 0.5883, Train Accuracy: 77.45%, Val Loss: 0.8171, Val Accuracy: 65.38%
# Epoch [192/250], Train Loss: 0.5695, Train Accuracy: 77.74%, Val Loss: 0.8264, Val Accuracy: 62.39%
# Epoch [193/250], Train Loss: 0.5925, Train Accuracy: 75.60%, Val Loss: 0.7716, Val Accuracy: 67.52%
# Epoch [194/250], Train Loss: 0.5634, Train Accuracy: 78.27%, Val Loss: 0.8633, Val Accuracy: 63.25%
# Epoch [195/250], Train Loss: 0.5767, Train Accuracy: 76.50%, Val Loss: 0.8509, Val Accuracy: 64.96%
# Epoch [196/250], Train Loss: 0.5802, Train Accuracy: 77.03%, Val Loss: 0.9222, Val Accuracy: 60.68%
# Epoch [197/250], Train Loss: 0.5318, Train Accuracy: 79.98%, Val Loss: 0.7485, Val Accuracy: 67.52%
# Epoch [198/250], Train Loss: 0.5239, Train Accuracy: 79.55%, Val Loss: 0.8189, Val Accuracy: 68.38%
# Epoch [199/250], Train Loss: 0.5556, Train Accuracy: 78.69%, Val Loss: 0.8410, Val Accuracy: 65.38%
# Epoch [200/250], Train Loss: 0.5501, Train Accuracy: 79.27%, Val Loss: 0.8380, Val Accuracy: 65.38%
# Epoch [201/250], Train Loss: 0.5387, Train Accuracy: 79.31%, Val Loss: 0.7754, Val Accuracy: 65.81%
# Epoch [202/250], Train Loss: 0.5041, Train Accuracy: 80.84%, Val Loss: 0.7590, Val Accuracy: 67.09%
# Epoch [203/250], Train Loss: 0.5345, Train Accuracy: 78.84%, Val Loss: 0.7793, Val Accuracy: 63.68%
# Epoch [204/250], Train Loss: 0.5140, Train Accuracy: 80.65%, Val Loss: 0.7807, Val Accuracy: 65.38%
# Epoch [205/250], Train Loss: 0.5640, Train Accuracy: 78.65%, Val Loss: 0.8552, Val Accuracy: 64.10%
# Epoch [206/250], Train Loss: 0.5506, Train Accuracy: 79.41%, Val Loss: 0.7977, Val Accuracy: 65.81%
# Epoch [207/250], Train Loss: 0.5710, Train Accuracy: 78.03%, Val Loss: 0.8834, Val Accuracy: 60.68%
# Epoch [208/250], Train Loss: 0.5515, Train Accuracy: 78.50%, Val Loss: 0.8255, Val Accuracy: 64.96%
# Epoch [209/250], Train Loss: 0.5669, Train Accuracy: 78.27%, Val Loss: 0.9932, Val Accuracy: 65.38%
# Epoch [210/250], Train Loss: 0.5759, Train Accuracy: 76.41%, Val Loss: 0.7979, Val Accuracy: 65.81%
# Epoch [211/250], Train Loss: 0.5316, Train Accuracy: 79.60%, Val Loss: 0.7511, Val Accuracy: 67.52%
# Epoch [212/250], Train Loss: 0.5131, Train Accuracy: 79.93%, Val Loss: 0.8623, Val Accuracy: 65.81%
# Epoch [213/250], Train Loss: 0.5300, Train Accuracy: 79.93%, Val Loss: 0.7665, Val Accuracy: 68.38%
# Epoch [214/250], Train Loss: 0.5276, Train Accuracy: 79.60%, Val Loss: 0.7074, Val Accuracy: 68.38%
# Epoch [215/250], Train Loss: 0.5010, Train Accuracy: 80.79%, Val Loss: 0.8059, Val Accuracy: 66.67%
# Epoch [216/250], Train Loss: 0.5314, Train Accuracy: 79.22%, Val Loss: 0.7580, Val Accuracy: 64.96%
# Epoch [217/250], Train Loss: 0.5221, Train Accuracy: 79.89%, Val Loss: 0.7799, Val Accuracy: 69.23%
# Epoch [218/250], Train Loss: 0.5031, Train Accuracy: 80.89%, Val Loss: 0.7745, Val Accuracy: 66.24%
# Epoch [219/250], Train Loss: 0.5286, Train Accuracy: 79.89%, Val Loss: 0.8807, Val Accuracy: 66.24%
# Epoch [220/250], Train Loss: 0.5381, Train Accuracy: 77.74%, Val Loss: 0.7769, Val Accuracy: 65.81%
# Epoch [221/250], Train Loss: 0.5290, Train Accuracy: 79.27%, Val Loss: 0.8008, Val Accuracy: 64.96%
# Epoch [222/250], Train Loss: 0.5349, Train Accuracy: 79.55%, Val Loss: 0.7817, Val Accuracy: 68.80%
# Epoch [223/250], Train Loss: 0.5160, Train Accuracy: 80.60%, Val Loss: 0.8335, Val Accuracy: 64.10%
# Epoch [224/250], Train Loss: 0.5006, Train Accuracy: 81.22%, Val Loss: 0.7601, Val Accuracy: 66.67%
# Epoch [225/250], Train Loss: 0.5220, Train Accuracy: 79.89%, Val Loss: 0.8104, Val Accuracy: 67.52%
# Epoch [226/250], Train Loss: 0.4973, Train Accuracy: 79.98%, Val Loss: 0.8268, Val Accuracy: 63.25%
# Epoch [227/250], Train Loss: 0.5005, Train Accuracy: 81.03%, Val Loss: 0.8941, Val Accuracy: 66.24%
# Epoch [228/250], Train Loss: 0.5097, Train Accuracy: 79.50%, Val Loss: 0.7944, Val Accuracy: 63.25%
# Epoch [229/250], Train Loss: 0.4866, Train Accuracy: 81.17%, Val Loss: 0.8388, Val Accuracy: 67.09%
# Epoch [230/250], Train Loss: 0.5045, Train Accuracy: 80.79%, Val Loss: 0.8130, Val Accuracy: 67.09%
# Epoch [231/250], Train Loss: 0.5251, Train Accuracy: 79.60%, Val Loss: 0.8059, Val Accuracy: 66.24%
# Epoch [232/250], Train Loss: 0.5219, Train Accuracy: 80.08%, Val Loss: 0.8065, Val Accuracy: 64.53%
# Epoch [233/250], Train Loss: 0.4913, Train Accuracy: 81.55%, Val Loss: 0.8712, Val Accuracy: 67.09%
# Epoch [234/250], Train Loss: 0.5221, Train Accuracy: 79.46%, Val Loss: 0.8234, Val Accuracy: 64.96%
# Epoch [235/250], Train Loss: 0.4930, Train Accuracy: 81.46%, Val Loss: 0.7559, Val Accuracy: 68.38%
# Epoch [236/250], Train Loss: 0.4841, Train Accuracy: 81.36%, Val Loss: 0.7354, Val Accuracy: 69.66%
# Epoch [237/250], Train Loss: 0.4844, Train Accuracy: 81.55%, Val Loss: 0.8667, Val Accuracy: 67.95%
# Epoch [238/250], Train Loss: 0.5161, Train Accuracy: 80.03%, Val Loss: 0.7407, Val Accuracy: 67.09%
# Epoch [239/250], Train Loss: 0.5302, Train Accuracy: 79.93%, Val Loss: 0.7811, Val Accuracy: 67.09%
# Epoch [240/250], Train Loss: 0.5287, Train Accuracy: 79.41%, Val Loss: 0.8130, Val Accuracy: 65.38%
# Epoch [241/250], Train Loss: 0.4798, Train Accuracy: 81.84%, Val Loss: 0.8400, Val Accuracy: 65.38%
# Epoch [242/250], Train Loss: 0.4847, Train Accuracy: 81.17%, Val Loss: 0.7430, Val Accuracy: 67.52%
# Epoch [243/250], Train Loss: 0.4951, Train Accuracy: 81.41%, Val Loss: 0.6964, Val Accuracy: 66.67%
# Epoch [244/250], Train Loss: 0.4746, Train Accuracy: 81.94%, Val Loss: 0.8292, Val Accuracy: 67.52%
# Epoch [245/250], Train Loss: 0.4960, Train Accuracy: 81.46%, Val Loss: 0.7587, Val Accuracy: 66.67%
# Epoch [246/250], Train Loss: 0.5132, Train Accuracy: 80.41%, Val Loss: 0.8453, Val Accuracy: 67.52%
# Epoch [247/250], Train Loss: 0.5033, Train Accuracy: 81.17%, Val Loss: 0.7391, Val Accuracy: 65.38%
# Epoch [248/250], Train Loss: 0.4633, Train Accuracy: 82.08%, Val Loss: 0.7861, Val Accuracy: 63.68%
# Epoch [249/250], Train Loss: 0.4856, Train Accuracy: 80.93%, Val Loss: 0.8392, Val Accuracy: 68.80%
# Epoch [250/250], Train Loss: 0.4916, Train Accuracy: 80.93%, Val Loss: 0.7686, Val Accuracy: 67.52%
# Final accuracy on test set: 66.54%
