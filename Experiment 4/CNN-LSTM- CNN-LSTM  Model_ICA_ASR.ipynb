# %%
import numpy as np
# Load the preprocessed data
X = np.load('X_all_ICA_ASR.npy')
Y = np.load('Y_all_ICA_ASR.npy')

# %%
import random
import torch
seed = 42
torch.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)

# %%
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset, random_split
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test=train_test_split(X,Y,test_size=.1,random_state=seed)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=seed)  # Split train into train (85%) and validation (15%)

X_train_flatten = X_train.reshape(-1, X_train.shape[-1])  # Shape: (num_train_epochs * num_channels, seq_len)
X_val_flatten = X_val.reshape(-1, X_val.shape[-1])        # Validation set
X_test_flatten = X_test.reshape(-1, X_test.shape[-1])  # Shape: (num_test_epochs * num_channels, seq_len)

mean = X_train_flatten.mean(axis=0)  # Compute the mean for each feature
X_train_centered = X_train_flatten - mean
X_val_centered = X_val_flatten - mean  # Center validation data using train set mean
X_test_centered = X_test_flatten - mean  # Apply the same mean to X_test

scaler = StandardScaler(with_mean=False)  # Disable mean subtraction since we already did it
X_train_scaled = scaler.fit_transform(X_train_centered)  # Fit on X_train
X_val_scaled = scaler.transform(X_val_centered)  # Apply the same scaler to validation data
X_test_scaled = scaler.transform(X_test_centered)  # Transform X_test using the same scaler

X_train_final = X_train_scaled.reshape(X_train.shape)  # Shape: (num_train_epochs, num_channels, seq_len)
X_val_final = X_val_scaled.reshape(X_val.shape)        # Shape: (num_val_epochs, num_channels, seq_len)
X_test_final = X_test_scaled.reshape(X_test.shape)  # Shape: (num_test_epochs, num_channels, seq_len)

print("Train set shape:", X_train_final.shape)
print("Validation set shape:", X_val_final.shape)
print("Test set shape:", X_test_final.shape)
# Out:
# Train set shape: (2098, 22, 1126)
# Validation set shape: (234, 22, 1126)
# Test set shape: (260, 22, 1126)

# %%
# 1. Convert Numpy Arrays to PyTorch Tensors
X_train1=torch.tensor(X_train_final,dtype=torch.float32)
X_val1=torch.tensor(X_val_final,dtype=torch.float32)
X_test1=torch.tensor(X_test_final,dtype=torch.float32)

y_train1=torch.tensor(y_train,dtype=torch.long)
y_val1=torch.tensor(y_val,dtype=torch.long)
y_test1=torch.tensor(y_test,dtype=torch.long)

# 2. Create TensorDatasets for Train, Validation, and Test Sets
train_dataset=TensorDataset(X_train1,y_train1)
val_dataset=TensorDataset(X_val1,y_val1)
test_dataset=TensorDataset(X_test1,y_test1)

# 3. Create DataLoaders for Batch Processing
train_loader=DataLoader(train_dataset,batch_size=100,shuffle=True)
val_loader=DataLoader(val_dataset,batch_size=100,shuffle=False)
test_loader=DataLoader(test_dataset,batch_size=100,shuffle=False)

# %%
import torch.nn as nn
import torch.optim as optim

# Define the CNN-LSTM model
class CNNLSTM(nn.Module):
    def __init__(self, input_channels, output_channel, lstm_hidden_dim1, lstm_hidden_dim2, output_channel2, num_classes):
        super(CNNLSTM, self).__init__()
        
        #First CNN Layer
        self.cnn = nn.Sequential(
            nn.Conv1d(input_channels, output_channel, padding=0, kernel_size=20, stride=4),
            nn.ReLU(),
            nn.BatchNorm1d(output_channel),
            nn.MaxPool1d(kernel_size=4, stride=4),
            nn.Dropout(0.5)
        )
        
        #First LSTM layers with bidirectional
        self.lstm1 = nn.LSTM(output_channel, hidden_size=lstm_hidden_dim1, num_layers=1, batch_first=True, bidirectional=True)
        self.dropout1 = nn.Dropout(0.5)
        
        #Second CNN Layer
        self.cnn2 = nn.Sequential(
            nn.Conv1d(lstm_hidden_dim1*2, output_channel2, padding=0, kernel_size=10, stride=4),
            nn.ReLU(),
            nn.BatchNorm1d(output_channel2),
            nn.MaxPool1d(kernel_size=4, stride=4),
            nn.Dropout(0.5)
        )
        
        #Second Lstm layer with bidirectional
        self.lstm2 = nn.LSTM(output_channel2, lstm_hidden_dim2, num_layers=1, batch_first=True, bidirectional=True)
        self.dropout2 = nn.Dropout(0.5)
        
        # Fully connected layer
        self.fc = nn.Linear(lstm_hidden_dim2 * 2 * 3, num_classes)
        self._initialize_weights()

    def forward(self, x):
        
        x = self.cnn(x)  # Apply CNN
        x = x.permute(0, 2, 1)  # Permute for LSTM (batch_size, seq_len, num_features)
        
        x, _ = self.lstm1(x)  # First LSTM layer
        x = self.dropout1(x)
        
        x = x.permute(0, 2, 1)  # Permute back for CNN
        x = self.cnn2(x)  # Apply second CNN layer
        
        x = x.permute(0, 2, 1)  # Permute for LSTM
        
        x, _ = self.lstm2(x) # Second LSTM layer
        x = self.dropout2(x)

        x = x.contiguous().view(x.size(0), -1)  # Flatten for FC layer
        x = self.fc(x)  # Apply fully connected layer
        return x

    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv1d) or isinstance(m, nn.Linear):
                nn.init.kaiming_normal_(m.weight, nonlinearity='relu')
                if m.bias is not None:
                    nn.init.zeros_(m.bias)
            elif isinstance(m, nn.LSTM):
                for name, param in m.named_parameters():
                    if 'weight_ih' in name:
                        nn.init.xavier_normal_(param)
                    elif 'weight_hh' in name:
                        nn.init.orthogonal_(param)
                    elif 'bias' in name:
                        nn.init.zeros_(param)
                        n = param.size(0)
                        param[n // 4:n // 2].data.fill_(1.0)  # Set forget gate bias to 1.0

input_channels = 22  
output_channel = 40
output_channel2 = 30
lstm_hidden_dim1 = 70
lstm_hidden_dim2 = 50
num_classes = 4  

# Instantiate the model
model = CNNLSTM(input_channels, output_channel, lstm_hidden_dim1, lstm_hidden_dim2, output_channel2, num_classes)
# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0007, weight_decay=.002)
# Training the model
num_epochs = 250
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct_train = 0
    total_train = 0

    # Training phase
    for inputs, labels in train_loader:
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        
        _, predicted = torch.max(outputs.data, 1)
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()

    train_accuracy = 100 * correct_train / total_train
    train_loss = running_loss / len(train_loader)
    
    # Validation phase
    model.eval()
    correct_val = 0
    total_val = 0
    running_val_loss = 0.0
    with torch.no_grad():
        for inputs, labels in val_loader:
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            running_val_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total_val += labels.size(0)
            correct_val += (predicted == labels).sum().item()

    val_accuracy = 100 * correct_val / total_val
    val_loss = running_val_loss / len(val_loader)
    
    print(f'Epoch [{epoch+1}/{num_epochs}], '
          f'Train Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.2f}%, '
          f'Val Loss: {val_loss:.4f}, Val Accuracy: {val_accuracy:.2f}%')
# Testing Phase
model.eval()
correct = 0
total = 0
with torch.no_grad():	
    for inputs, labels in test_loader:
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

final_accuracy = 100 * correct / total
print(f'Final accuracy on test set: {final_accuracy:.2f}%')
# Out:
# Epoch [1/250], Train Loss: 1.4411, Train Accuracy: 24.93%, Val Loss: 1.3705, Val Accuracy: 34.62%
# Epoch [2/250], Train Loss: 1.4354, Train Accuracy: 24.93%, Val Loss: 1.3637, Val Accuracy: 30.77%
# Epoch [3/250], Train Loss: 1.4104, Train Accuracy: 28.17%, Val Loss: 1.3647, Val Accuracy: 32.05%
# Epoch [4/250], Train Loss: 1.4019, Train Accuracy: 27.50%, Val Loss: 1.3550, Val Accuracy: 35.47%
# Epoch [5/250], Train Loss: 1.3927, Train Accuracy: 27.45%, Val Loss: 1.3444, Val Accuracy: 34.62%
# Epoch [6/250], Train Loss: 1.3813, Train Accuracy: 28.60%, Val Loss: 1.3355, Val Accuracy: 37.18%
# Epoch [7/250], Train Loss: 1.3603, Train Accuracy: 30.74%, Val Loss: 1.3277, Val Accuracy: 34.62%
# Epoch [8/250], Train Loss: 1.3464, Train Accuracy: 33.70%, Val Loss: 1.3073, Val Accuracy: 36.32%
# Epoch [9/250], Train Loss: 1.3327, Train Accuracy: 34.65%, Val Loss: 1.3220, Val Accuracy: 33.33%
# Epoch [10/250], Train Loss: 1.3246, Train Accuracy: 35.51%, Val Loss: 1.2934, Val Accuracy: 38.03%
# Epoch [11/250], Train Loss: 1.3112, Train Accuracy: 36.46%, Val Loss: 1.2867, Val Accuracy: 37.18%
# Epoch [12/250], Train Loss: 1.2743, Train Accuracy: 38.89%, Val Loss: 1.2354, Val Accuracy: 37.61%
# Epoch [13/250], Train Loss: 1.2721, Train Accuracy: 37.75%, Val Loss: 1.2004, Val Accuracy: 42.74%
# Epoch [14/250], Train Loss: 1.2433, Train Accuracy: 42.09%, Val Loss: 1.2463, Val Accuracy: 38.89%
# Epoch [15/250], Train Loss: 1.2424, Train Accuracy: 41.66%, Val Loss: 1.2103, Val Accuracy: 44.02%
# Epoch [16/250], Train Loss: 1.2265, Train Accuracy: 43.14%, Val Loss: 1.1142, Val Accuracy: 45.73%
# Epoch [17/250], Train Loss: 1.1983, Train Accuracy: 43.95%, Val Loss: 1.0839, Val Accuracy: 47.44%
# Epoch [18/250], Train Loss: 1.1765, Train Accuracy: 44.76%, Val Loss: 1.1030, Val Accuracy: 49.15%
# Epoch [19/250], Train Loss: 1.1701, Train Accuracy: 46.14%, Val Loss: 1.1185, Val Accuracy: 49.15%
# Epoch [20/250], Train Loss: 1.1623, Train Accuracy: 47.76%, Val Loss: 1.0756, Val Accuracy: 47.01%
# Epoch [21/250], Train Loss: 1.1434, Train Accuracy: 48.00%, Val Loss: 1.0872, Val Accuracy: 46.58%
# Epoch [22/250], Train Loss: 1.1464, Train Accuracy: 48.05%, Val Loss: 1.0849, Val Accuracy: 53.85%
# Epoch [23/250], Train Loss: 1.1245, Train Accuracy: 48.86%, Val Loss: 1.0829, Val Accuracy: 50.43%
# Epoch [24/250], Train Loss: 1.0880, Train Accuracy: 51.19%, Val Loss: 1.0846, Val Accuracy: 50.43%
# Epoch [25/250], Train Loss: 1.1035, Train Accuracy: 50.71%, Val Loss: 1.0626, Val Accuracy: 50.43%
# Epoch [26/250], Train Loss: 1.0885, Train Accuracy: 51.05%, Val Loss: 1.0038, Val Accuracy: 50.00%
# Epoch [27/250], Train Loss: 1.0908, Train Accuracy: 50.91%, Val Loss: 1.0523, Val Accuracy: 48.29%
# Epoch [28/250], Train Loss: 1.0565, Train Accuracy: 53.67%, Val Loss: 1.0161, Val Accuracy: 52.56%
# Epoch [29/250], Train Loss: 1.0612, Train Accuracy: 52.14%, Val Loss: 1.0313, Val Accuracy: 50.85%
# Epoch [30/250], Train Loss: 1.0506, Train Accuracy: 52.91%, Val Loss: 1.0098, Val Accuracy: 52.14%
# Epoch [31/250], Train Loss: 1.0361, Train Accuracy: 54.10%, Val Loss: 0.9628, Val Accuracy: 54.70%
# Epoch [32/250], Train Loss: 1.0474, Train Accuracy: 54.00%, Val Loss: 1.0678, Val Accuracy: 52.14%
# Epoch [33/250], Train Loss: 1.0174, Train Accuracy: 55.43%, Val Loss: 0.9678, Val Accuracy: 52.56%
# Epoch [34/250], Train Loss: 1.0272, Train Accuracy: 53.72%, Val Loss: 0.9223, Val Accuracy: 54.27%
# Epoch [35/250], Train Loss: 1.0114, Train Accuracy: 56.10%, Val Loss: 0.8969, Val Accuracy: 55.98%
# Epoch [36/250], Train Loss: 1.0042, Train Accuracy: 56.34%, Val Loss: 0.9376, Val Accuracy: 53.42%
# Epoch [37/250], Train Loss: 0.9973, Train Accuracy: 56.29%, Val Loss: 0.9225, Val Accuracy: 55.13%
# Epoch [38/250], Train Loss: 0.9888, Train Accuracy: 56.34%, Val Loss: 0.9500, Val Accuracy: 55.56%
# Epoch [39/250], Train Loss: 0.9768, Train Accuracy: 57.05%, Val Loss: 0.9006, Val Accuracy: 58.12%
# Epoch [40/250], Train Loss: 0.9794, Train Accuracy: 57.20%, Val Loss: 0.9665, Val Accuracy: 55.13%
# Epoch [41/250], Train Loss: 0.9825, Train Accuracy: 58.06%, Val Loss: 0.9275, Val Accuracy: 54.27%
# Epoch [42/250], Train Loss: 0.9810, Train Accuracy: 57.48%, Val Loss: 0.8886, Val Accuracy: 55.98%
# Epoch [43/250], Train Loss: 0.9649, Train Accuracy: 58.44%, Val Loss: 0.9118, Val Accuracy: 55.98%
# Epoch [44/250], Train Loss: 0.9424, Train Accuracy: 58.72%, Val Loss: 0.8630, Val Accuracy: 59.83%
# Epoch [45/250], Train Loss: 0.9507, Train Accuracy: 57.91%, Val Loss: 0.8620, Val Accuracy: 59.83%
# Epoch [46/250], Train Loss: 0.9471, Train Accuracy: 57.86%, Val Loss: 0.9165, Val Accuracy: 59.40%
# Epoch [47/250], Train Loss: 0.9403, Train Accuracy: 59.68%, Val Loss: 0.9449, Val Accuracy: 53.85%
# Epoch [48/250], Train Loss: 0.9309, Train Accuracy: 59.87%, Val Loss: 0.8761, Val Accuracy: 58.97%
# Epoch [49/250], Train Loss: 0.9093, Train Accuracy: 61.25%, Val Loss: 0.8720, Val Accuracy: 57.26%
# Epoch [50/250], Train Loss: 0.8925, Train Accuracy: 61.63%, Val Loss: 0.9270, Val Accuracy: 58.97%
# Epoch [51/250], Train Loss: 0.9338, Train Accuracy: 58.58%, Val Loss: 0.9267, Val Accuracy: 58.12%
# Epoch [52/250], Train Loss: 0.9118, Train Accuracy: 60.96%, Val Loss: 0.9495, Val Accuracy: 56.41%
# Epoch [53/250], Train Loss: 0.8880, Train Accuracy: 63.06%, Val Loss: 0.9301, Val Accuracy: 58.55%
# Epoch [54/250], Train Loss: 0.8874, Train Accuracy: 63.39%, Val Loss: 1.0260, Val Accuracy: 55.56%
# Epoch [55/250], Train Loss: 0.8891, Train Accuracy: 62.25%, Val Loss: 0.9289, Val Accuracy: 60.68%
# Epoch [56/250], Train Loss: 0.8778, Train Accuracy: 62.87%, Val Loss: 0.8385, Val Accuracy: 62.39%
# Epoch [57/250], Train Loss: 0.8479, Train Accuracy: 65.92%, Val Loss: 0.9998, Val Accuracy: 55.56%
# Epoch [58/250], Train Loss: 0.8620, Train Accuracy: 63.87%, Val Loss: 0.8398, Val Accuracy: 61.11%
# Epoch [59/250], Train Loss: 0.8397, Train Accuracy: 66.25%, Val Loss: 0.8215, Val Accuracy: 62.39%
# Epoch [60/250], Train Loss: 0.8604, Train Accuracy: 63.73%, Val Loss: 0.8540, Val Accuracy: 60.68%
# Epoch [61/250], Train Loss: 0.8680, Train Accuracy: 62.96%, Val Loss: 0.9444, Val Accuracy: 58.12%
# Epoch [62/250], Train Loss: 0.8463, Train Accuracy: 65.25%, Val Loss: 0.9606, Val Accuracy: 55.13%
# Epoch [63/250], Train Loss: 0.8445, Train Accuracy: 65.63%, Val Loss: 0.8938, Val Accuracy: 55.56%
# Epoch [64/250], Train Loss: 0.8254, Train Accuracy: 66.06%, Val Loss: 0.8633, Val Accuracy: 63.25%
# Epoch [65/250], Train Loss: 0.8046, Train Accuracy: 68.02%, Val Loss: 0.8472, Val Accuracy: 61.97%
# Epoch [66/250], Train Loss: 0.8106, Train Accuracy: 66.78%, Val Loss: 0.8876, Val Accuracy: 58.97%
# Epoch [67/250], Train Loss: 0.8331, Train Accuracy: 66.16%, Val Loss: 0.9237, Val Accuracy: 60.26%
# Epoch [68/250], Train Loss: 0.8061, Train Accuracy: 67.06%, Val Loss: 1.0246, Val Accuracy: 55.56%
# Epoch [69/250], Train Loss: 0.8143, Train Accuracy: 65.44%, Val Loss: 0.8584, Val Accuracy: 63.25%
# Epoch [70/250], Train Loss: 0.7992, Train Accuracy: 66.49%, Val Loss: 0.8129, Val Accuracy: 63.25%
# Epoch [71/250], Train Loss: 0.7910, Train Accuracy: 67.54%, Val Loss: 0.8893, Val Accuracy: 60.68%
# Epoch [72/250], Train Loss: 0.8131, Train Accuracy: 66.68%, Val Loss: 0.8690, Val Accuracy: 63.68%
# Epoch [73/250], Train Loss: 0.8089, Train Accuracy: 67.30%, Val Loss: 0.8852, Val Accuracy: 61.54%
# Epoch [74/250], Train Loss: 0.7768, Train Accuracy: 68.83%, Val Loss: 0.9231, Val Accuracy: 61.54%
# Epoch [75/250], Train Loss: 0.7626, Train Accuracy: 70.69%, Val Loss: 0.8636, Val Accuracy: 63.68%
# Epoch [76/250], Train Loss: 0.7805, Train Accuracy: 68.26%, Val Loss: 1.1554, Val Accuracy: 53.85%
# Epoch [77/250], Train Loss: 0.7711, Train Accuracy: 69.02%, Val Loss: 0.8260, Val Accuracy: 63.25%
# Epoch [78/250], Train Loss: 0.7722, Train Accuracy: 68.45%, Val Loss: 0.8393, Val Accuracy: 61.97%
# Epoch [79/250], Train Loss: 0.7432, Train Accuracy: 69.73%, Val Loss: 0.8601, Val Accuracy: 62.39%
# Epoch [80/250], Train Loss: 0.7580, Train Accuracy: 68.45%, Val Loss: 0.9548, Val Accuracy: 57.69%
# Epoch [81/250], Train Loss: 0.7340, Train Accuracy: 70.59%, Val Loss: 0.8335, Val Accuracy: 65.38%
# Epoch [82/250], Train Loss: 0.7242, Train Accuracy: 72.50%, Val Loss: 0.8455, Val Accuracy: 64.53%
# Epoch [83/250], Train Loss: 0.7551, Train Accuracy: 69.35%, Val Loss: 0.8964, Val Accuracy: 61.11%
# Epoch [84/250], Train Loss: 0.7508, Train Accuracy: 69.49%, Val Loss: 0.9491, Val Accuracy: 59.40%
# Epoch [85/250], Train Loss: 0.7398, Train Accuracy: 70.59%, Val Loss: 0.9293, Val Accuracy: 58.97%
# Epoch [86/250], Train Loss: 0.7217, Train Accuracy: 71.50%, Val Loss: 0.8783, Val Accuracy: 62.39%
# Epoch [87/250], Train Loss: 0.7251, Train Accuracy: 70.64%, Val Loss: 0.9648, Val Accuracy: 60.68%
# Epoch [88/250], Train Loss: 0.7316, Train Accuracy: 71.07%, Val Loss: 0.8821, Val Accuracy: 60.26%
# Epoch [89/250], Train Loss: 0.7339, Train Accuracy: 70.54%, Val Loss: 0.8348, Val Accuracy: 64.10%
# Epoch [90/250], Train Loss: 0.7375, Train Accuracy: 70.88%, Val Loss: 0.8827, Val Accuracy: 61.97%
# Epoch [91/250], Train Loss: 0.7302, Train Accuracy: 71.12%, Val Loss: 0.8962, Val Accuracy: 61.54%
# Epoch [92/250], Train Loss: 0.7150, Train Accuracy: 71.78%, Val Loss: 0.7914, Val Accuracy: 67.09%
# Epoch [93/250], Train Loss: 0.7123, Train Accuracy: 71.83%, Val Loss: 0.8195, Val Accuracy: 64.53%
# Epoch [94/250], Train Loss: 0.7133, Train Accuracy: 70.83%, Val Loss: 0.8585, Val Accuracy: 61.11%
# Epoch [95/250], Train Loss: 0.7054, Train Accuracy: 72.74%, Val Loss: 0.8657, Val Accuracy: 62.39%
# Epoch [96/250], Train Loss: 0.6920, Train Accuracy: 73.31%, Val Loss: 0.8493, Val Accuracy: 65.38%
# Epoch [97/250], Train Loss: 0.7037, Train Accuracy: 72.55%, Val Loss: 0.8135, Val Accuracy: 64.96%
# Epoch [98/250], Train Loss: 0.6952, Train Accuracy: 71.50%, Val Loss: 0.8115, Val Accuracy: 67.52%
# Epoch [99/250], Train Loss: 0.6850, Train Accuracy: 73.21%, Val Loss: 0.8248, Val Accuracy: 67.52%
# Epoch [100/250], Train Loss: 0.6748, Train Accuracy: 72.83%, Val Loss: 0.8181, Val Accuracy: 67.09%
# Epoch [101/250], Train Loss: 0.6740, Train Accuracy: 72.40%, Val Loss: 0.8793, Val Accuracy: 63.68%
# Epoch [102/250], Train Loss: 0.6404, Train Accuracy: 75.41%, Val Loss: 0.8081, Val Accuracy: 64.96%
# Epoch [103/250], Train Loss: 0.6764, Train Accuracy: 72.93%, Val Loss: 0.7856, Val Accuracy: 68.80%
# Epoch [104/250], Train Loss: 0.6631, Train Accuracy: 74.55%, Val Loss: 0.8464, Val Accuracy: 63.25%
# Epoch [105/250], Train Loss: 0.6773, Train Accuracy: 73.55%, Val Loss: 0.9211, Val Accuracy: 61.11%
# Epoch [106/250], Train Loss: 0.6646, Train Accuracy: 72.83%, Val Loss: 0.8057, Val Accuracy: 68.80%
# Epoch [107/250], Train Loss: 0.6397, Train Accuracy: 75.55%, Val Loss: 0.8818, Val Accuracy: 66.24%
# Epoch [108/250], Train Loss: 0.6296, Train Accuracy: 74.74%, Val Loss: 0.8320, Val Accuracy: 67.52%
# Epoch [109/250], Train Loss: 0.6604, Train Accuracy: 74.40%, Val Loss: 0.7828, Val Accuracy: 68.80%
# Epoch [110/250], Train Loss: 0.6416, Train Accuracy: 74.98%, Val Loss: 0.8525, Val Accuracy: 65.81%
# Epoch [111/250], Train Loss: 0.6274, Train Accuracy: 75.45%, Val Loss: 0.9083, Val Accuracy: 62.39%
# Epoch [112/250], Train Loss: 0.6345, Train Accuracy: 74.93%, Val Loss: 0.9429, Val Accuracy: 62.39%
# Epoch [113/250], Train Loss: 0.6684, Train Accuracy: 73.16%, Val Loss: 0.8349, Val Accuracy: 62.82%
# Epoch [114/250], Train Loss: 0.6372, Train Accuracy: 74.55%, Val Loss: 0.8131, Val Accuracy: 63.68%
# Epoch [115/250], Train Loss: 0.6341, Train Accuracy: 74.98%, Val Loss: 0.8529, Val Accuracy: 63.68%
# Epoch [116/250], Train Loss: 0.6433, Train Accuracy: 74.88%, Val Loss: 0.9688, Val Accuracy: 62.82%
# Epoch [117/250], Train Loss: 0.6716, Train Accuracy: 73.69%, Val Loss: 1.0329, Val Accuracy: 57.69%
# Epoch [118/250], Train Loss: 0.6035, Train Accuracy: 77.50%, Val Loss: 0.7329, Val Accuracy: 70.94%
# Epoch [119/250], Train Loss: 0.6012, Train Accuracy: 75.88%, Val Loss: 0.7070, Val Accuracy: 64.96%
# Epoch [120/250], Train Loss: 0.6172, Train Accuracy: 75.93%, Val Loss: 0.7704, Val Accuracy: 70.51%
# Epoch [121/250], Train Loss: 0.6230, Train Accuracy: 75.02%, Val Loss: 0.8217, Val Accuracy: 66.24%
# Epoch [122/250], Train Loss: 0.6207, Train Accuracy: 75.83%, Val Loss: 0.8862, Val Accuracy: 62.39%
# Epoch [123/250], Train Loss: 0.6104, Train Accuracy: 76.50%, Val Loss: 0.7962, Val Accuracy: 67.09%
# Epoch [124/250], Train Loss: 0.5968, Train Accuracy: 77.07%, Val Loss: 0.7890, Val Accuracy: 69.66%
# Epoch [125/250], Train Loss: 0.5714, Train Accuracy: 77.74%, Val Loss: 0.7543, Val Accuracy: 69.66%
# Epoch [126/250], Train Loss: 0.5966, Train Accuracy: 77.03%, Val Loss: 0.8618, Val Accuracy: 63.25%
# Epoch [127/250], Train Loss: 0.5773, Train Accuracy: 77.36%, Val Loss: 0.7900, Val Accuracy: 70.09%
# Epoch [128/250], Train Loss: 0.6043, Train Accuracy: 76.31%, Val Loss: 0.7638, Val Accuracy: 69.23%
# Epoch [129/250], Train Loss: 0.6088, Train Accuracy: 76.79%, Val Loss: 1.0650, Val Accuracy: 59.40%
# Epoch [130/250], Train Loss: 0.5854, Train Accuracy: 77.41%, Val Loss: 0.8511, Val Accuracy: 66.67%
# Epoch [131/250], Train Loss: 0.5865, Train Accuracy: 77.12%, Val Loss: 0.8128, Val Accuracy: 68.38%
# Epoch [132/250], Train Loss: 0.6045, Train Accuracy: 75.64%, Val Loss: 0.8762, Val Accuracy: 65.81%
# Epoch [133/250], Train Loss: 0.5824, Train Accuracy: 78.31%, Val Loss: 0.9107, Val Accuracy: 64.10%
# Epoch [134/250], Train Loss: 0.5797, Train Accuracy: 77.74%, Val Loss: 0.7588, Val Accuracy: 66.67%
# Epoch [135/250], Train Loss: 0.5877, Train Accuracy: 76.64%, Val Loss: 0.7897, Val Accuracy: 67.52%
# Epoch [136/250], Train Loss: 0.5701, Train Accuracy: 77.74%, Val Loss: 0.8285, Val Accuracy: 65.38%
# Epoch [137/250], Train Loss: 0.6112, Train Accuracy: 76.98%, Val Loss: 0.7852, Val Accuracy: 66.24%
# Epoch [138/250], Train Loss: 0.5677, Train Accuracy: 78.31%, Val Loss: 0.8262, Val Accuracy: 67.09%
# Epoch [139/250], Train Loss: 0.5670, Train Accuracy: 77.45%, Val Loss: 0.8279, Val Accuracy: 64.96%
# Epoch [140/250], Train Loss: 0.5595, Train Accuracy: 79.03%, Val Loss: 0.8486, Val Accuracy: 65.81%
# Epoch [141/250], Train Loss: 0.5364, Train Accuracy: 78.84%, Val Loss: 0.9802, Val Accuracy: 62.82%
# Epoch [142/250], Train Loss: 0.5893, Train Accuracy: 78.31%, Val Loss: 0.8271, Val Accuracy: 67.52%
# Epoch [143/250], Train Loss: 0.5497, Train Accuracy: 78.84%, Val Loss: 0.8074, Val Accuracy: 67.52%
# Epoch [144/250], Train Loss: 0.5777, Train Accuracy: 78.46%, Val Loss: 0.8351, Val Accuracy: 68.38%
# Epoch [145/250], Train Loss: 0.5743, Train Accuracy: 77.55%, Val Loss: 0.8932, Val Accuracy: 65.38%
# Epoch [146/250], Train Loss: 0.5347, Train Accuracy: 80.17%, Val Loss: 0.8980, Val Accuracy: 64.96%
# Epoch [147/250], Train Loss: 0.5700, Train Accuracy: 79.03%, Val Loss: 0.8174, Val Accuracy: 67.52%
# Epoch [148/250], Train Loss: 0.5513, Train Accuracy: 78.98%, Val Loss: 0.9288, Val Accuracy: 67.52%
# Epoch [149/250], Train Loss: 0.5619, Train Accuracy: 78.79%, Val Loss: 0.7348, Val Accuracy: 68.38%
# Epoch [150/250], Train Loss: 0.5343, Train Accuracy: 79.22%, Val Loss: 0.9078, Val Accuracy: 66.24%
# Epoch [151/250], Train Loss: 0.5415, Train Accuracy: 78.93%, Val Loss: 0.9305, Val Accuracy: 64.10%
# Epoch [152/250], Train Loss: 0.5528, Train Accuracy: 78.98%, Val Loss: 0.7831, Val Accuracy: 67.52%
# Epoch [153/250], Train Loss: 0.5369, Train Accuracy: 78.60%, Val Loss: 0.8336, Val Accuracy: 67.09%
# Epoch [154/250], Train Loss: 0.5477, Train Accuracy: 78.88%, Val Loss: 0.8278, Val Accuracy: 69.23%
# Epoch [155/250], Train Loss: 0.5276, Train Accuracy: 80.22%, Val Loss: 0.7498, Val Accuracy: 68.80%
# Epoch [156/250], Train Loss: 0.5275, Train Accuracy: 79.98%, Val Loss: 0.8329, Val Accuracy: 65.81%
# Epoch [157/250], Train Loss: 0.5104, Train Accuracy: 80.84%, Val Loss: 0.9746, Val Accuracy: 64.53%
# Epoch [158/250], Train Loss: 0.5492, Train Accuracy: 78.93%, Val Loss: 0.7457, Val Accuracy: 70.51%
# Epoch [159/250], Train Loss: 0.5273, Train Accuracy: 79.74%, Val Loss: 0.7397, Val Accuracy: 67.95%
# Epoch [160/250], Train Loss: 0.5328, Train Accuracy: 79.03%, Val Loss: 0.9370, Val Accuracy: 64.10%
# Epoch [161/250], Train Loss: 0.5448, Train Accuracy: 78.84%, Val Loss: 0.8093, Val Accuracy: 66.67%
# Epoch [162/250], Train Loss: 0.5151, Train Accuracy: 80.03%, Val Loss: 0.7575, Val Accuracy: 70.09%
# Epoch [163/250], Train Loss: 0.5009, Train Accuracy: 80.41%, Val Loss: 0.7576, Val Accuracy: 70.94%
# Epoch [164/250], Train Loss: 0.5322, Train Accuracy: 79.60%, Val Loss: 0.7086, Val Accuracy: 70.51%
# Epoch [165/250], Train Loss: 0.5139, Train Accuracy: 81.03%, Val Loss: 0.7909, Val Accuracy: 68.80%
# Epoch [166/250], Train Loss: 0.5114, Train Accuracy: 79.84%, Val Loss: 0.8490, Val Accuracy: 65.38%
# Epoch [167/250], Train Loss: 0.5420, Train Accuracy: 79.55%, Val Loss: 0.8245, Val Accuracy: 69.66%
# Epoch [168/250], Train Loss: 0.4987, Train Accuracy: 80.51%, Val Loss: 0.8088, Val Accuracy: 67.52%
# Epoch [169/250], Train Loss: 0.5142, Train Accuracy: 80.65%, Val Loss: 0.7275, Val Accuracy: 69.23%
# Epoch [170/250], Train Loss: 0.5242, Train Accuracy: 80.36%, Val Loss: 0.7458, Val Accuracy: 70.51%
# Epoch [171/250], Train Loss: 0.5033, Train Accuracy: 80.79%, Val Loss: 0.7211, Val Accuracy: 73.08%
# Epoch [172/250], Train Loss: 0.5109, Train Accuracy: 79.89%, Val Loss: 0.7943, Val Accuracy: 65.81%
# Epoch [173/250], Train Loss: 0.4991, Train Accuracy: 80.51%, Val Loss: 0.9009, Val Accuracy: 64.53%
# Epoch [174/250], Train Loss: 0.5105, Train Accuracy: 81.12%, Val Loss: 0.8778, Val Accuracy: 66.67%
# Epoch [175/250], Train Loss: 0.5140, Train Accuracy: 80.89%, Val Loss: 0.7999, Val Accuracy: 68.80%
# Epoch [176/250], Train Loss: 0.4611, Train Accuracy: 82.27%, Val Loss: 0.7487, Val Accuracy: 70.94%
# Epoch [177/250], Train Loss: 0.4971, Train Accuracy: 81.27%, Val Loss: 0.8119, Val Accuracy: 69.66%
# Epoch [178/250], Train Loss: 0.5166, Train Accuracy: 81.03%, Val Loss: 0.8757, Val Accuracy: 66.24%
# Epoch [179/250], Train Loss: 0.5061, Train Accuracy: 81.03%, Val Loss: 0.7804, Val Accuracy: 68.38%
# Epoch [180/250], Train Loss: 0.4822, Train Accuracy: 81.51%, Val Loss: 0.7455, Val Accuracy: 70.94%
# Epoch [181/250], Train Loss: 0.5074, Train Accuracy: 80.17%, Val Loss: 0.7586, Val Accuracy: 68.80%
# Epoch [182/250], Train Loss: 0.4721, Train Accuracy: 81.74%, Val Loss: 0.7565, Val Accuracy: 68.80%
# Epoch [183/250], Train Loss: 0.4962, Train Accuracy: 81.65%, Val Loss: 0.8036, Val Accuracy: 68.38%
# Epoch [184/250], Train Loss: 0.5030, Train Accuracy: 81.27%, Val Loss: 0.8047, Val Accuracy: 67.52%
# Epoch [185/250], Train Loss: 0.5042, Train Accuracy: 80.51%, Val Loss: 0.7694, Val Accuracy: 73.50%
# Epoch [186/250], Train Loss: 0.4581, Train Accuracy: 82.75%, Val Loss: 0.8119, Val Accuracy: 69.23%
# Epoch [187/250], Train Loss: 0.4751, Train Accuracy: 82.41%, Val Loss: 0.8898, Val Accuracy: 68.80%
# Epoch [188/250], Train Loss: 0.4921, Train Accuracy: 81.27%, Val Loss: 0.8296, Val Accuracy: 70.51%
# Epoch [189/250], Train Loss: 0.4922, Train Accuracy: 81.36%, Val Loss: 0.8296, Val Accuracy: 67.52%
# Epoch [190/250], Train Loss: 0.4593, Train Accuracy: 83.22%, Val Loss: 0.7908, Val Accuracy: 69.23%
# Epoch [191/250], Train Loss: 0.4839, Train Accuracy: 81.84%, Val Loss: 0.7807, Val Accuracy: 68.38%
# Epoch [192/250], Train Loss: 0.4762, Train Accuracy: 81.41%, Val Loss: 0.7355, Val Accuracy: 72.22%
# Epoch [193/250], Train Loss: 0.4555, Train Accuracy: 82.08%, Val Loss: 0.8228, Val Accuracy: 69.23%
# Epoch [194/250], Train Loss: 0.5097, Train Accuracy: 80.17%, Val Loss: 0.8314, Val Accuracy: 70.51%
# Epoch [195/250], Train Loss: 0.4806, Train Accuracy: 81.36%, Val Loss: 0.7753, Val Accuracy: 68.38%
# Epoch [196/250], Train Loss: 0.4706, Train Accuracy: 81.98%, Val Loss: 0.7502, Val Accuracy: 69.66%
# Epoch [197/250], Train Loss: 0.4505, Train Accuracy: 82.70%, Val Loss: 0.7023, Val Accuracy: 68.38%
# Epoch [198/250], Train Loss: 0.4413, Train Accuracy: 82.75%, Val Loss: 0.8418, Val Accuracy: 68.80%
# Epoch [199/250], Train Loss: 0.4554, Train Accuracy: 82.65%, Val Loss: 0.8364, Val Accuracy: 68.80%
# Epoch [200/250], Train Loss: 0.4314, Train Accuracy: 82.98%, Val Loss: 0.8254, Val Accuracy: 67.95%
# Epoch [201/250], Train Loss: 0.4598, Train Accuracy: 82.98%, Val Loss: 0.7596, Val Accuracy: 73.08%
# Epoch [202/250], Train Loss: 0.4517, Train Accuracy: 82.89%, Val Loss: 0.9270, Val Accuracy: 66.67%
# Epoch [203/250], Train Loss: 0.4623, Train Accuracy: 82.94%, Val Loss: 0.9870, Val Accuracy: 64.10%
# Epoch [204/250], Train Loss: 0.4706, Train Accuracy: 82.46%, Val Loss: 0.7649, Val Accuracy: 70.51%
# Epoch [205/250], Train Loss: 0.4531, Train Accuracy: 82.41%, Val Loss: 0.8519, Val Accuracy: 67.09%
# Epoch [206/250], Train Loss: 0.4592, Train Accuracy: 82.36%, Val Loss: 0.7866, Val Accuracy: 70.51%
# Epoch [207/250], Train Loss: 0.4309, Train Accuracy: 84.37%, Val Loss: 0.7865, Val Accuracy: 70.51%
# Epoch [208/250], Train Loss: 0.4406, Train Accuracy: 83.46%, Val Loss: 0.7725, Val Accuracy: 69.23%
# Epoch [209/250], Train Loss: 0.4642, Train Accuracy: 81.98%, Val Loss: 0.9134, Val Accuracy: 66.24%
# Epoch [210/250], Train Loss: 0.4637, Train Accuracy: 82.27%, Val Loss: 0.8325, Val Accuracy: 67.95%
# Epoch [211/250], Train Loss: 0.4487, Train Accuracy: 83.70%, Val Loss: 0.7848, Val Accuracy: 69.66%
# Epoch [212/250], Train Loss: 0.4439, Train Accuracy: 83.75%, Val Loss: 0.7449, Val Accuracy: 71.37%
# Epoch [213/250], Train Loss: 0.4158, Train Accuracy: 84.75%, Val Loss: 0.7983, Val Accuracy: 67.52%
# Epoch [214/250], Train Loss: 0.4341, Train Accuracy: 84.70%, Val Loss: 0.7295, Val Accuracy: 73.08%
# Epoch [215/250], Train Loss: 0.4340, Train Accuracy: 83.60%, Val Loss: 0.8450, Val Accuracy: 67.95%
# Epoch [216/250], Train Loss: 0.4761, Train Accuracy: 82.94%, Val Loss: 0.9708, Val Accuracy: 64.53%
# Epoch [217/250], Train Loss: 0.4598, Train Accuracy: 82.27%, Val Loss: 0.8105, Val Accuracy: 67.09%
# Epoch [218/250], Train Loss: 0.4558, Train Accuracy: 83.22%, Val Loss: 0.8121, Val Accuracy: 71.79%
# Epoch [219/250], Train Loss: 0.4358, Train Accuracy: 83.70%, Val Loss: 0.8668, Val Accuracy: 67.09%
# Epoch [220/250], Train Loss: 0.4413, Train Accuracy: 83.41%, Val Loss: 0.8314, Val Accuracy: 67.52%
# Epoch [221/250], Train Loss: 0.4096, Train Accuracy: 84.75%, Val Loss: 0.7994, Val Accuracy: 69.23%
# Epoch [222/250], Train Loss: 0.4279, Train Accuracy: 83.22%, Val Loss: 0.7571, Val Accuracy: 68.80%
# Epoch [223/250], Train Loss: 0.4103, Train Accuracy: 84.70%, Val Loss: 0.8646, Val Accuracy: 67.52%
# Epoch [224/250], Train Loss: 0.4277, Train Accuracy: 84.37%, Val Loss: 0.8633, Val Accuracy: 68.80%
# Epoch [225/250], Train Loss: 0.4523, Train Accuracy: 81.84%, Val Loss: 0.7846, Val Accuracy: 68.38%
# Epoch [226/250], Train Loss: 0.4477, Train Accuracy: 83.51%, Val Loss: 0.7663, Val Accuracy: 70.51%
# Epoch [227/250], Train Loss: 0.4297, Train Accuracy: 83.84%, Val Loss: 0.7996, Val Accuracy: 68.80%
# Epoch [228/250], Train Loss: 0.4172, Train Accuracy: 84.13%, Val Loss: 0.7367, Val Accuracy: 71.79%
# Epoch [229/250], Train Loss: 0.4283, Train Accuracy: 82.70%, Val Loss: 0.8884, Val Accuracy: 65.38%
# Epoch [230/250], Train Loss: 0.4319, Train Accuracy: 83.75%, Val Loss: 0.8676, Val Accuracy: 67.52%
# Epoch [231/250], Train Loss: 0.4424, Train Accuracy: 82.51%, Val Loss: 0.8279, Val Accuracy: 68.38%
# Epoch [232/250], Train Loss: 0.4359, Train Accuracy: 83.17%, Val Loss: 0.8110, Val Accuracy: 69.23%
# Epoch [233/250], Train Loss: 0.4229, Train Accuracy: 83.51%, Val Loss: 0.7694, Val Accuracy: 70.51%
# Epoch [234/250], Train Loss: 0.4443, Train Accuracy: 83.17%, Val Loss: 0.7744, Val Accuracy: 69.66%
# Epoch [235/250], Train Loss: 0.4271, Train Accuracy: 84.03%, Val Loss: 0.7906, Val Accuracy: 70.94%
# Epoch [236/250], Train Loss: 0.3917, Train Accuracy: 85.46%, Val Loss: 0.8021, Val Accuracy: 73.08%
# Epoch [237/250], Train Loss: 0.4116, Train Accuracy: 85.94%, Val Loss: 0.8782, Val Accuracy: 69.23%
# Epoch [238/250], Train Loss: 0.4042, Train Accuracy: 85.41%, Val Loss: 0.8615, Val Accuracy: 69.23%
# Epoch [239/250], Train Loss: 0.4227, Train Accuracy: 84.89%, Val Loss: 0.7559, Val Accuracy: 72.22%
# Epoch [240/250], Train Loss: 0.4402, Train Accuracy: 82.75%, Val Loss: 0.7738, Val Accuracy: 71.37%
# Epoch [241/250], Train Loss: 0.3993, Train Accuracy: 84.94%, Val Loss: 0.8535, Val Accuracy: 70.51%
# Epoch [242/250], Train Loss: 0.4487, Train Accuracy: 83.32%, Val Loss: 0.8302, Val Accuracy: 67.95%
# Epoch [243/250], Train Loss: 0.4257, Train Accuracy: 83.84%, Val Loss: 0.9864, Val Accuracy: 63.68%
# Epoch [244/250], Train Loss: 0.4288, Train Accuracy: 83.56%, Val Loss: 0.8077, Val Accuracy: 69.66%
# Epoch [245/250], Train Loss: 0.4004, Train Accuracy: 84.94%, Val Loss: 0.7477, Val Accuracy: 72.65%
# Epoch [246/250], Train Loss: 0.3767, Train Accuracy: 86.32%, Val Loss: 0.8079, Val Accuracy: 70.94%
# Epoch [247/250], Train Loss: 0.4279, Train Accuracy: 84.13%, Val Loss: 0.8354, Val Accuracy: 68.38%
# Epoch [248/250], Train Loss: 0.4201, Train Accuracy: 83.41%, Val Loss: 0.8620, Val Accuracy: 67.52%
# Epoch [249/250], Train Loss: 0.4170, Train Accuracy: 84.18%, Val Loss: 0.7915, Val Accuracy: 69.66%
# Epoch [250/250], Train Loss: 0.3997, Train Accuracy: 84.70%, Val Loss: 0.8218, Val Accuracy: 69.23%
# Final accuracy on test set: 71.15%
